# %%
1+2-3
# Out:
# 0

# %%
12+4-5
# Out:
# 11

# %%
2^10
# Out:
# 1024

# %%
sin (pi/2)
# Out:
# 1

# %%
sin(pi/2)
# Out:
# 1

# %%
sin(0.1)
# Out:
# 0.0998334166468282

# %%
14+2*(5-3)
# Out:
# 18

# %%
14+2*(5-3)
# Out:
# 18

# %%
x= var('x')

eq1= x^4-3/2*x^3-x+3/2==0
solve(eq1,x)
# Out:
# [x == 1, x == (3/2), x == -1/2*I*sqrt(3) - 1/2, x == 1/2*I*sqrt(3) - 1/2]

# %%
x = var('x')
eq1= sqrt(x^2+2*x)==3
solve(eq1,x)
# Out:
# [x == -sqrt(10) - 1, x == sqrt(10) - 1]

# %%
x = var('x')
y = var('y')
eq= [2*x+y == 3, x+3*y==-1]
solve(eq,x,y)
# Out:
# [[x == 2, y == -1]]

# %%
x= var('x')
y= var('y')
eq= [2*x+x*y+2*y == 59, 3*x-2*x*y+3*y == -34]
solve(eq,x,y)
# Out:
# [[x == 7, y == 5], [x == 5, y == 7]]

# %%
limit(sin(x)/x , x=0)
# Out:
# 1

# %%
limit(x^3+3*x^2-5/2*x^3-7*x, x= infinity)
# Out:
# -Infinity

# %%
limit(cos(x)+1/x-pi, x = pi)
# Out:
# -pi + 1/pi - 1

# %%
y(x)=3*x^3+2*x^2-5
diff(y(x),x)
# Out:
# 9*x^2 + 4*x

# %%
y(x)= sqrt(1+x^4)
diff(y(x),x)
# Out:
# 2*x^3/sqrt(x^4 + 1)

# %%
y(x)= e^x*sin(x)*cos(x)
diff(y(x),x)
# Out:
# cos(x)^2*e^x + cos(x)*e^x*sin(x) - e^x*sin(x)^2

# %%
x = var('x')
integrate(e*x^3+2*x^2-5,x,0,1)
# Out:
# 1/4*e - 13/3

# %%
x = var('x')
integrate(1/x^2,x,1,infinity)
# Out:
# 1

# %%
x = var('x')
integrate(e^-x^2,x,-infinity,infinity)
# Out:
# sqrt(pi)

# %%
f(x) = e^-x -1
plot(f(x),-2,2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f(x)=(200*e^(-0.5*x)) /(2*(e^(0.5*x) -1)+100)
plot(f(x),0,50)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f(x)=x*sin(1/x)
plot(f(x),-3,3)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
t=var('t')
x(t)=(1-cos(t))*cos(t)
y(t)=(1-cos(t))*sin(t)
parametric_plot((x(t),y(t)),(t,0,2*pi))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
t=var('t')
x(t)=sin(3*t)*cos(t)
y(t)=sin(3*t)*sin(t)
parametric_plot((x(t),(y(t))),(t,0, 2*pi))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
t=var('t')
x(t)= t-sin(t)
y(t)=1-cos(t)
parametric_plot((x(t),y(t)),(t,0,6*pi))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
t=var('t')
x(t)=cos(t)+(cos(7*t)/2)+(sin(17*t)/3)
y(t)=sin(t)+(sin(7*t)/2)+(cos(17*t)/3)
parametric_plot((x(t),y(t)),(t,0,2*pi))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x,y = var('x,y')
f(x,y)= x^2+y^2-2*x-4*y+4
implicit_plot(f(x)==0,(x,-4,5),(y,-2,7))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x,y = var('x,y')
f(x,y)=x^2-2*x*y-y^2
implicit_plot(f(x)==1 ,(x,-12,21),(y,-5,8))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x,y = var('x,y')
f(x,y)=6*x^2-4*x*y+0*y^2-4*x-32*y-7
implicit_plot(f(x)==0 ,(x,-12,21),(y,-5,8))
# Out:
# Graphics object consisting of 1 graphics primitive
