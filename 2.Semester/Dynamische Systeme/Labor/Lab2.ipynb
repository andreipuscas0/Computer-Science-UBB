# %%
reset()
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==2*x*y
desolve(eqd,y)
# Out:
# _C*e^(x^2)

# %%
sol=desolve(eqd,y)
_C=var('_C')
sol1=sol.substitute(_C==1)
plot(sol1,x,-10,10,ymin=-10,ymax=10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
reset()
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==y/x
desolve(eqd,y)
# Out:
# _C*x

# %%
sol=desolve(eqd,y)
_C=var('_C')
sol2=sol.substitute(_C==2)
plot(sol2,x,-10,10,ymin=-10,ymax=10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
reset()
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==2*x*(1+y^2)
desolve(eqd,y)
# Out:
# 1/2*arctan(y(x)) == 1/2*x^2 + _C

# %%
sol=desolve(eqd,y)
yy=var('yy')
_C=var('_C')
f(x,yy,_C)=sol.substitute(y(x)==yy)
implicit_plot(f(x,yy,0),(x,-10,10),(yy,-10,10))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
reset()
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==(-2*x*y^2)/(x^2-1)
desolve(eqd,y)
# Out:
# 1/2/y(x) == _C + 1/2*log(x + 1) + 1/2*log(x - 1)

# %%
sol=desolve(eqd,y)
yy=var('yy')
_C=var('_C')
f(x,yy,_C)=sol.substitute(y(x)==yy)
implicit_plot(f(x,yy,0),(x,-10,10),(yy,-10,10))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
reset()
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==(1/cos(x))-y*tan(x)
desolve(eqd,y)
# Out:
# (_C + tan(x))/sec(x)

# %%
sol=desolve(eqd,y)
_C=var('_C')
sol4=sol.substitute(_C==1)
plot(sol4,x,2,5)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
reset()
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==x^3-(2/x)*y
desolve(eqd,y)
# Out:
# 1/6*(x^6 + 6*_C)/x^2

# %%
sol=desolve(eqd,y)
_C=var('_C')
sol5=sol.substitute(_C==0)
plot(sol5,x,2,5)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
reset()
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==3*x-(1/x)*y
desolve(eqd,y)
# Out:
# (x^3 + _C)/x

# %%
sol=desolve(eqd,y)
_C=var('_C')
sol6=sol.substitute(_C==0)
plot(sol6,x,-10,10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
reset()
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==1+y^2
desolve(eqd,y,ics=[0,1])
# Out:
# arctan(y(x)) == 1/4*pi + x

# %%
sol=desolve(eqd,y,ics=[0,1])
yy=var('yy')
_C=var('_C')
f(x,yy,_C)=sol.substitute(y(x)==yy)
implicit_plot(f(x,yy,0),(x,-10,10),(yy,-10,10))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
reset()
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==-x^2+2*y
desolve(eqd,y,ics=[0,1/4])
# Out:
# 1/2*x^2 + 1/2*x + 1/4

# %%
sol=desolve(eqd,y)
_C=var('_C')
sol7=sol.substitute(_C==1)
plot(sol7,x,-10,10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
reset()
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==(1/cos(x))-y*tan(x)
desolve(eqd,y,ics=[0,0])
# Out:
# tan(x)/sec(x)

# %%
sol=desolve(eqd,y)
_C=var('_C')
sol8=sol.substitute(_C==0)
plot(sol8,x,-10,10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
reset()

# %%
x, k = var('x, k')
y = function('y')(x)
DGL = diff(y, x) == x ^ 3 - k / x * y
sol = desolve(DGL, [y, x])
sol
# Out:
# (x^4*x^k/(k + 4) + _C)/x^k

# %%
_C = var('_C')
sol1 = sol.substitute(_C == 0)
sol1 = sol1.substitute(k == 1)
sol1
# Out:
# 1/5*x^4

# %%
plot(sol1, x, -20, 20)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
DGL
# Out:
# diff(y(x), x) == x^3 - k*y(x)/x

# %%
DGL1 = DGL.substitute(k == 1)
DGL1
# Out:
# diff(y(x), x) == x^3 - y(x)/x

# %%
sol = desolve(DGL1, y, ics = [1, 0])
sol
# Out:
# 1/5*(x^5 - 1)/x

# %%
plot(sol, x, 10, 20)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
system = [sol];
for i in [0..10]:
    DGL1 = DGL.substitute(k == i)
    sol = desolve(DGL1, y, ics = [1, 0])
    system += [sol]
system
# Out:
# [1/5*(x^5 - 1)/x,
#  1/4*x^4 - 1/4,
#  1/5*(x^5 - 1)/x,
#  1/6*(x^6 - 1)/x^2,
#  1/7*(x^7 - 1)/x^3,
#  1/8*(x^8 - 1)/x^4,
#  1/9*(x^9 - 1)/x^5,
#  1/10*(x^10 - 1)/x^6,
#  1/11*(x^11 - 1)/x^7,
#  1/12*(x^12 - 1)/x^8,
#  1/13*(x^13 - 1)/x^9,
#  1/14*(x^14 - 1)/x^10]

# %%
DGL = diff(y, x) - 1 / 2 * y == cos(x)
sol = desolve(DGL, y)
sol
# Out:
# -1/5*(2*(cos(x) - 2*sin(x))*e^(-1/2*x) - 5*_C)*e^(1/2*x)

# %%
system = [sol];
for i in [-10..10]:
    sol = desolve(DGL, y, ics = [0, i])
    system += [sol]
system
# Out:
# [-1/5*(2*(cos(x) - 2*sin(x))*e^(-1/2*x) - 5*_C)*e^(1/2*x),
#  -2/5*cos(x) - 48/5*e^(1/2*x) + 4/5*sin(x),
#  -2/5*cos(x) - 43/5*e^(1/2*x) + 4/5*sin(x),
#  -2/5*cos(x) - 38/5*e^(1/2*x) + 4/5*sin(x),
#  -2/5*cos(x) - 33/5*e^(1/2*x) + 4/5*sin(x),
#  -2/5*cos(x) - 28/5*e^(1/2*x) + 4/5*sin(x),
#  -2/5*cos(x) - 23/5*e^(1/2*x) + 4/5*sin(x),
#  -2/5*cos(x) - 18/5*e^(1/2*x) + 4/5*sin(x),
#  -2/5*cos(x) - 13/5*e^(1/2*x) + 4/5*sin(x),
#  -2/5*cos(x) - 8/5*e^(1/2*x) + 4/5*sin(x),
#  -2/5*cos(x) - 3/5*e^(1/2*x) + 4/5*sin(x),
#  -2/5*cos(x) + 2/5*e^(1/2*x) + 4/5*sin(x),
#  -2/5*cos(x) + 7/5*e^(1/2*x) + 4/5*sin(x),
#  -2/5*cos(x) + 12/5*e^(1/2*x) + 4/5*sin(x),
#  -2/5*cos(x) + 17/5*e^(1/2*x) + 4/5*sin(x),
#  -2/5*cos(x) + 22/5*e^(1/2*x) + 4/5*sin(x),
#  -2/5*cos(x) + 27/5*e^(1/2*x) + 4/5*sin(x),
#  -2/5*cos(x) + 32/5*e^(1/2*x) + 4/5*sin(x),
#  -2/5*cos(x) + 37/5*e^(1/2*x) + 4/5*sin(x),
#  -2/5*cos(x) + 42/5*e^(1/2*x) + 4/5*sin(x),
#  -2/5*cos(x) + 47/5*e^(1/2*x) + 4/5*sin(x),
# ...

# %%
sol = desolve(DGL, y, ics = [0, 0])
sol
# Out:
# -2/5*cos(x) + 2/5*e^(1/2*x) + 4/5*sin(x)

# %%
sol = desolve(DGL, y, ics = [0, pi])
sol
# Out:
# 1/5*(5*pi + 2)*e^(1/2*x) - 2/5*cos(x) + 4/5*sin(x)

# %%
a = var('a')
sol = desolve(DGL, y, ics = [0, a])
sol
# Out:
# 1/5*(5*a + 2)*e^(1/2*x) - 2/5*cos(x) + 4/5*sin(x)

# %%
sol1.substitute(a == -2 / 5)
sol1
# Out:
# 1/5*x^4

# %%
#a0 == -2/5
plot([sol.substitute(a == -3), sol.substitute(a == - 2 / 5), sol.substitute(a == 1)], x, -10, 10,ymin = -10, ymax=10)
# Out:
# Graphics object consisting of 3 graphics primitives

# %% [markdown]
# ###
